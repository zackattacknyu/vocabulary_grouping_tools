# %%
from vocabulary_grouping_tools.ingestion.api_ingest import get_english_translation
import pandas as pd
import yaml

# %%
from vocabulary_grouping_tools.grouping.grouping_tools import make_all_subseqs

# %%
secrets = yaml.safe_load(open('../metadata/secrets.yml', 'r'))

# %%
vocab = pd.read_csv('../input_files_from_output/vocab_ak_1_2_ttmik_1_2_w_hanja_refined.csv')

# %%
vocab
# Out:
#      Unnamed: 0 hangul_word               english_phrase hanja_word
# 0             0          휴대               being portable         携帶
# 1             1           형  elder brother from male pov        NaN
# 2             2        피곤하다                        tired        NaN
# 3             3          포도                        grape         葡萄
# 4             4           팔                  arm | eight        NaN
# ..          ...         ...                          ...        ...
# 554         554          가족                       family         家族
# 555         555          가방                          bag         街坊
# 556         556        가르치다                     to teach        NaN
# 557         557          가다                        to go        NaN
# 558         558          가게                 store / shop        NaN
#
# [559 rows x 4 columns]

# %%
hanja_words = [_word for _word in vocab['hanja_word'] if str(_word) != 'nan']

# %%
def cutoff_ending(hanja_word):
    if hanja_word.endswith('하다'):
        return hanja_word[:-2]
    elif hanja_word.endswith('다'):
        return hanja_word[:-1]
    else:
        return hanja_word

# %%
subseq_set = set()
for hangul_wrd in list(hanja_words):
    subseq_set.update(make_all_subseqs(cutoff_ending(hangul_wrd)))

# %%
subseq_set
# Out:
# {'一',
#  '一月',
#  '三',
#  '三月',
#  '下',
#  '下鐵',
#  '下鐵驛',
#  '中',
#  '中國',
#  '中國語',
#  '中學',
#  '中學生',
#  '主',
#  '九',
#  '九月',
#  '乳',
#  '事',
#  '事務',
#  '事務室',
#  '二',
#  '二月',
#  '五',
#  '五月',
#  '仁',
#  '仁川',
#  '仁川空',
#  '仁川空港',
#  '今',
#  '他',
#  '休',
#  '休暇',
#  '住',
#  '住所',
#  '來',
#  '來日',
#  '便',
#  '便紙',
#  '健',
#  '健康',
#  '傘',
#  '內',
#  '公',
#  '公園',
#  '其',
#  '其他',
#  '典',
#  '冊',
#  '冊床',
#  '冊房',
#  '冷',
#  '冷藏',
#  '冷藏庫',
#  '冷麵',
#  '出',
#  '出發',
#  '分',
#  '初',
#  '初等',
#  '初等學',
#  '初等學生',
#  '利',
#  '利用',
#  '前',
#  '劇',
#  '劇場',
#  '動',
#  '務',
#  '務室',
#  '包',
#  '化',
#  '化粧',
#  '化粧室',
#  '匣',
#  '十',
#  '十一',
#  '十一月',
#  '十二',
#  '十二月',
#  '十月',
#  '十萬',
#  '午',
#  '午前',
#  '午後',
#  '口',
#  '口頭',
#  '只',
#  '只今',
#  '同',
#  '同生',
#  '員',
#  '問',
#  '四',
#  '四月',
#  '國',
#  '國籍',
#  '國語',
#  '園',
#  '圖',
#  '圖書',
#  '圖書館',
#  '土',
#  '土曜',
#  '土曜日',
#  '地',
#  '地下',
#  '地下鐵',
#  '地下鐵驛',
#  '坊',
#  '堂',
#  '場',
#  '夕',
#  '外',
#  '外國',
#  '大',
#  '大學',
#  '大學生',
#  '夫',
#  '女',
#  '女同',
#  '女同生',
#  '女子',
#  '姓',
#  '姓銜',
#  '婚',
#  '子',
#  '學',
#  '學校',
#  '學生',
#  '室',
#  '家',
#  '家族',
#  '宿',
#  '宿舍',
#  '宿題',
#  '寄',
#  '寄宿',
#  '寄宿舍',
#  '寢',
#  '寢臺',
#  '寫',
#  '寫眞',
#  '小',
#  '小包',
#  '局',
#  '山',
#  '島',
#  '川',
#  '川空',
#  '川空港',
#  '州',
#  '州島',
#  '工',
#  '工夫',
#  '市',
#  '市內',
#  '市場',
#  '市廳',
#  '師',
#  '帶',
#  '常',
#  '帽',
#  '帽子',
#  '年',
#  '床',
#  '店',
#  '庫',
#  '康',
#  '廳',
#  '後',
#  '心',
#  '恒',
#  '恒常',
#  '悶',
#  '感',
#  '感氣',
#  '房',
#  '所',
#  '投',
#  '投票',
#  '拏',
#  '拏山',
#  '拳',
#  '拳道',
#  '掃',
#  '携',
#  '携帶',
#  '放',
#  '放學',
#  '敎',
#  '敎室',
#  '料',
#  '料理',
#  '料理師',
#  '料金',
#  '新',
#  '新聞',
#  '旅',
#  '旅行',
#  '旅行社',
#  '族',
#  '日',
#  '日曜',
#  '日曜日',
#  '日本',
#  '日本語',
#  '日記',
#  '映',
#  '映畵',
#  '昨',
#  '昨年',
#  '時',
#  '時計',
#  '時間',
#  '時間表',
#  '暇',
#  '曜',
#  '曜日',
#  '書',
#  '書館',
#  '會',
#  '會社',
#  '會社員',
#  '月',
#  '月曜',
#  '月曜日',
#  '服',
#  '木',
#  '木曜',
#  '木曜日',
#  '末',
#  '本',
#  '本語',
#  '束',
#  '果',
#  '校',
#  '案',
#  '案內',
#  '椅',
#  '椅子',
#  '業',
#  '樂',
#  '機',
#  '每',
#  '每日',
#  '氣',
#  '氣分',
#  '水',
#  '水曜',
#  '水曜日',
#  '水泳',
#  '水泳場',
#  '汽',
#  '汽車',
#  '沙',
#  '沙果',
#  '泳',
#  '泳場',
#  '洗',
#  '洗濯',
#  '洗濯所',
#  '洲',
#  '淸',
#  '淸掃',
#  '港',
#  '溫',
#  '溫突',
#  '溫突房',
#  '漢',
#  '漢拏',
#  '漢拏山',
#  '濟',
#  '濟州',
#  '濟州島',
#  '濠',
#  '濠洲',
#  '濯',
#  '濯所',
#  '火',
#  '火曜',
#  '火曜日',
#  '灰',
#  '灰色',
#  '牛',
#  '牛乳',
#  '獨',
#  '獨逸',
#  '球',
#  '理',
#  '理師',
#  '生',
#  '生日',
#  '生鮮',
#  '生鮮膾',
#  '用',
#  '男',
#  '男便',
#  '男子',
#  '番',
#  '番號',
#  '畵',
#  '病',
#  '病院',
#  '登',
#  '登山',
#  '發',
#  '百',
#  '百貨',
#  '百貨店',
#  '看',
#  '看護',
#  '看護師',
#  '眞',
#  '硏',
#  '硏究',
#  '硏究員',
#  '社',
#  '社員',
#  '票',
#  '秋',
#  '秋夕',
#  '究',
#  '究員',
#  '空',
#  '空冊',
#  '空港',
#  '突',
#  '突房',
#  '窓',
#  '窓門',
#  '筆',
#  '等',
#  '等學',
#  '等學生',
#  '籍',
#  '粧',
#  '粧室',
#  '約',
#  '約束',
#  '紅',
#  '紅茶',
#  '紙',
#  '紙匣',
#  '結',
#  '結婚',
#  '綠',
#  '綠色',
#  '綠茶',
#  '線',
#  '美',
#  '美國',
#  '者',
#  '聞',
#  '職',
#  '職員',
#  '職業',
#  '膾',
#  '自',
#  '自主',
#  '自轉',
#  '自轉車',
#  '至',
#  '至難',
#  '臺',
#  '舊',
#  '舍',
#  '色',
#  '苦',
#  '苦悶',
#  '英',
#  '英國',
#  '英語',
#  '茶',
#  '菜',
#  '萄',
#  '萬',
#  '葉',
#  '葉書',
#  '葡',
#  '葡萄',
#  '薇',
#  '薔',
#  '薔薇',
#  '藏',
#  '藏庫',
#  '藥',
#  '藥局',
#  '號',
#  '號線',
#  '行',
#  '行員',
#  '行機',
#  '行社',
#  '街',
#  '街坊',
#  '表',
#  '褐',
#  '褐色',
#  '親',
#  '親舊',
#  '計',
#  '記',
#  '記者',
#  '試',
#  '試驗',
#  '話',
#  '話番',
#  '話番號',
#  '語',
#  '護',
#  '護師',
#  '貨',
#  '貨店',
#  '質',
#  '質問',
#  '跆',
#  '跆拳',
#  '跆拳道',
#  '蹴',
#  '蹴球',
#  '車',
#  '車場',
#  '轉',
#  '轉車',
#  '辭',
#  '辭典',
#  '週',
#  '週日',
#  '週末',
#  '逸',
#  '運',
#  '運動',
#  '運轉',
#  '道',
#  '遞',
#  '遞局',
#  '郵',
#  '郵遞',
#  '郵遞局',
#  '酒',
#  '醫',
#  '醫師',
#  '野',
#  '野球',
#  '野菜',
#  '金',
#  '金曜',
#  '金曜日',
#  '釜',
#  '釜山',
#  '鉛',
#  '鉛筆',
#  '銀',
#  '銀行',
#  '銀行員',
#  '銜',
#  '鐵',
#  '鐵驛',
#  '門',
#  '間',
#  '間表',
#  '院',
#  '難',
#  '雨',
#  '雨傘',
#  '電',
#  '電話',
#  '電話番',
#  '電話番號',
#  '韓',
#  '韓國',
#  '韓國語',
#  '韓服',
#  '音',
#  '音樂',
#  '頭',
#  '題',
#  '飛',
#  '飛行',
#  '飛行機',
#  '食',
#  '食堂',
#  '飮',
#  '飮食',
#  '館',
#  '駐',
#  '駐車',
#  '駐車場',
#  '驗',
#  '驛',
#  '高',
#  '高等',
#  '高等學',
#  '高等學生',
#  '鮮',
#  '鮮膾',
#  '鳴',
#  '鳴動',
#  '麥',
#  '麥酒',
#  '麵',
#  '點',
#  '點心'}

# %%
len(subseq_set)
# Out:
# 502

# %%
secrets
# Out:
# {'client_id': 'WyPCRsYaxeKJ748sfFdV', 'client_secret': 'EFpX_fxYpo'}

# %%
translation_for_subseq = {}
for subseq in subseq_set:
    print('Now getting translation for ' + subseq)
    english_trans = get_english_translation(subseq, secrets['client_id'],
                                            secrets['client_secret'],
                                            source_language='zh-TW')
    print(f'Translation is {english_trans}')
    print()
    translation_for_subseq[subseq] = english_trans
# Out:
# Now getting translation for 初
# Translation is at first time
#
# Now getting translation for 生鮮膾
# Translation is raw and fresh meat and vegetable dish
#
# Now getting translation for 冊
# Translation is book
#
# Now getting translation for 秋
# Translation is autumn
#
# Now getting translation for 獨
# Translation is alone
#
# Now getting translation for 冊床
# Translation is a bookmaking
#
# Now getting translation for 金
# Translation is gold
#
# Now getting translation for 火
# Translation is fire
#
# Now getting translation for 萄
# Translation is grape
#
# Now getting translation for 寫
# Translation is write
#
# Now getting translation for 傘
# Translation is umbrella
#
# Now getting translation for 寄宿舍
# Translation is boarding house
#
# Now getting translation for 曜
# Translation is burn
#
# Now getting translation for 主
# Translation is master
#
# Now getting translation for 一月
# Translation is January
#
# Now getting translation for 中國
# Translation is China
#
# Now getting translation for 看
# Translation is Look.
#
# Now getting translation for 火曜日
# Translation is obsidian day
#
# Now getting translation for 鮮
# Translation is fresh
#
# Now getting translation for 表
# Translation is watch
#
# Now getting translation for 十一月
# Translation is November
#
# Now getting translation for 昨
# Translation is yesterday
#
# Now getting translation for 水曜
# Translation is water observation
#
# Now getting translation for 九月
# Translation is September
#
# Now getting translation for 機
# Translation is machine
#
# Now getting translation for 突房
# Translation is an out-of a house
#
# Now getting translation for 銀
# Translation is silver
#
# Now getting translation for 轉車
# Translation is change trains
#
# Now getting translation for 社員
# Translation is a member
#
# Now getting translation for 職員
# Translation is staff
#
# Now getting translation for 銀行員
# Translation is banker
#
# Now getting translation for 膾
# Translation is popularity
#
# Now getting translation for 携
# Translation is carry
#
# Now getting translation for 野菜
# Translation is wild vegetables
#
# Now getting translation for 發
# Translation is emit
#
# Now getting translation for 沙果
# Translation is fruit of sand fruit
#
# Now getting translation for 褐
# Translation is brown
#
# Now getting translation for 理
# Translation is reason
#
# Now getting translation for 堂
# Translation is class
#
# Now getting translation for 三月
# Translation is March
#
# Now getting translation for 病院
# Translation is a hospital
#
# Now getting translation for 淸
# Translation is clear
#
# Now getting translation for 結
# Translation is conclude
#
# Now getting translation for 中
# Translation is hit the wind
#
# Now getting translation for 鳴動
# Translation is chime
#
# Now getting translation for 自轉
# Translation is spin
#
# Now getting translation for 薇
# Translation is wee
#
# Now getting translation for 乳
# Translation is milk
#
# Now getting translation for 百貨
# Translation is department store
#
# Now getting translation for 臺
# Translation is platform
#
# Now getting translation for 放學
# Translation is leave school
#
# Now getting translation for 薔
# Translation is rose
#
# Now getting translation for 投票
# Translation is cast one's ballot
#
# Now getting translation for 劇場
# Translation is theater
#
# Now getting translation for 冷
# Translation is cold
#
# Now getting translation for 番號
# Translation is designation
#
# Now getting translation for 外
# Translation is outside
#
# Now getting translation for 鉛
# Translation is lead
#
# Now getting translation for 學校
# Translation is school
#
# Now getting translation for 院
# Translation is yard
#
# Now getting translation for 藏
# Translation is hide
#
# Now getting translation for 紅茶
# Translation is black tea
#
# Now getting translation for 轉
# Translation is turn
#
# Now getting translation for 地下
# Translation is underground
#
# Now getting translation for 社
# Translation is company
#
# Now getting translation for 動
# Translation is move
#
# Now getting translation for 場
# Translation is yard
#
# Now getting translation for 遞局
# Translation is delivery department
#
# Now getting translation for 床
# Translation is bed
#
# Now getting translation for 姓銜
# Translation is title
#
# Now getting translation for 韓
# Translation is Korean
#
# Now getting translation for 書
# Translation is book
#
# Now getting translation for 生鮮
# Translation is fresh
#
# Now getting translation for 行機
# Translation is action
#
# Now getting translation for 婚
# Translation is get married
#
# Now getting translation for 員
# Translation is crew
#
# Now getting translation for 本語
# Translation is one's native language
#
# Now getting translation for 百
# Translation is hundred
#
# Now getting translation for 寄宿
# Translation is board
#
# Now getting translation for 秋夕
# Translation is autumn evening
#
# Now getting translation for 圖
# Translation is plan
#
# Now getting translation for 者
# Translation is person
#
# Now getting translation for 家
# Translation is home
#
# Now getting translation for 漢拏山
# Translation is Mt. Hanyeol Mountain
#
# Now getting translation for 休
# Translation is break
#
# Now getting translation for 貨店
# Translation is a shop
#
# Now getting translation for 葉
# Translation is leaf
#
# Now getting translation for 市
# Translation is market
#
# Now getting translation for 男子
# Translation is a man
#
# Now getting translation for 務
# Translation is do
#
# Now getting translation for 只今
# Translation is only now
#
# Now getting translation for 包
# Translation is bag
#
# Now getting translation for 駐車
# Translation is parking
#
# Now getting translation for 冊房
# Translation is a bookshop
#
# Now getting translation for 間表
# Translation is an interval table
#
# Now getting translation for 樂
# Translation is pleasant
#
# Now getting translation for 紅
# Translation is red
#
# Now getting translation for 等
# Translation is Wait.
#
# Now getting translation for 門
# Translation is door
#
# Now getting translation for 新
# Translation is fresh
#
# Now getting translation for 辭
# Translation is decline
#
# Now getting translation for 紙匣
# Translation is a paper box
#
# Now getting translation for 女同生
# Translation is a coed student
#
# Now getting translation for 運動
# Translation is exercise
#
# Now getting translation for 旅行社
# Translation is travel agency
#
# Now getting translation for 木曜日
# Translation is obsidian day
#
# Now getting translation for 便
# Translation is be convenience
#
# Now getting translation for 州
# Translation is a state
#
# Now getting translation for 職業
# Translation is occupation
#
# Now getting translation for 美
# Translation is pretty
#
# Now getting translation for 所
# Translation is circumstance
#
# Now getting translation for 登
# Translation is mount
#
# Now getting translation for 室
# Translation is chamber
#
# Now getting translation for 仁川
# Translation is Incheon, Republic of
#
# Now getting translation for 飛行
# Translation is fly
#
# Now getting translation for 日曜
# Translation is observation
#
# Now getting translation for 木
# Translation is wood
#
# Now getting translation for 麥
# Translation is wheat
#
# Now getting translation for 硏究
# Translation is study
#
# Now getting translation for 用
# Translation is use
#
# Now getting translation for 大
# Translation is big
#
# Now getting translation for 鐵
# Translation is iron
#
# Now getting translation for 姓
# Translation is family name
#
# Now getting translation for 英國
# Translation is the United Kingdom
#
# Now getting translation for 住
# Translation is Stay.
#
# Now getting translation for 其
# Translation is that
#
# Now getting translation for 粧
# Translation is make up
#
# Now getting translation for 匣
# Translation is box
#
# Now getting translation for 宿題
# Translation is a long-standing problem
#
# Now getting translation for 其他
# Translation is Other
#
# Now getting translation for 土
# Translation is earth
#
# Now getting translation for 工夫
# Translation is effort
#
# Now getting translation for 濟州島
# Translation is Jeju Island
#
# Now getting translation for 暇
# Translation is spare time
#
# Now getting translation for 悶
# Translation is stuffy
#
# Now getting translation for 事務室
# Translation is office
#
# Now getting translation for 水曜日
# Translation is obsidian day of water
#
# Now getting translation for 時計
# Translation is a time
#
# Now getting translation for 藥局
# Translation is pharmacy
#
# Now getting translation for 溫突
# Translation is warm
#
# Now getting translation for 護
# Translation is protect
#
# Now getting translation for 化粧
# Translation is make-up
#
# Now getting translation for 駐車場
# Translation is parking lot
#
# Now getting translation for 拳道
# Translation is kwondo; kwondo.
#
# Now getting translation for 十月
# Translation is October
#
# Now getting translation for 眞
# Translation is Really?
#
# Now getting translation for 時間
# Translation is time
#
# Now getting translation for 窓
# Translation is 窓
#
# Now getting translation for 計
# Translation is plan
#
# Now getting translation for 週末
# Translation is weekend
#
# Now getting translation for 電話番號
# Translation is a telephone number
#
# Now getting translation for 蹴
# Translation is kick
#
# Now getting translation for 等學
# Translation is wait for a lesson
#
# Now getting translation for 高等學
# Translation is higher learning
#
# Now getting translation for 韓服
# Translation is hanbok
#
# Now getting translation for 服
# Translation is comply
#
# Now getting translation for 粧室
# Translation is dressing room
#
# Now getting translation for 水
# Translation is water
#
# Now getting translation for 等學生
# Translation is wait for a student
#
# Now getting translation for 男
# Translation is man
#
# Now getting translation for 試驗
# Translation is experiment
#
# Now getting translation for 恒常
# Translation is constantly
#
# Now getting translation for 椅子
# Translation is chair
#
# Now getting translation for 綠色
# Translation is green
#
# Now getting translation for 四
# Translation is four
#
# Now getting translation for 運
# Translation is carry
#
# Now getting translation for 口頭
# Translation is a word of mouth
#
# Now getting translation for 四月
# Translation is April
#
# Now getting translation for 外國
# Translation is foreign country
#
# Now getting translation for 大學
# Translation is university
#
# Now getting translation for 山
# Translation is mountain
#
# Now getting translation for 飛
# Translation is fly
#
# Now getting translation for 藥
# Translation is medicine
#
# Now getting translation for 灰色
# Translation is grayish
#
# Now getting translation for 英
# Translation is English
#
# Now getting translation for 生日
# Translation is birthday
#
# Now getting translation for 點心
# Translation is confection
#
# Now getting translation for 國語
# Translation is national language
#
# Now getting translation for 日本
# Translation is Japan
#
# Now getting translation for 間
# Translation is sometime
#
# Now getting translation for 沙
# Translation is sand
#
# Now getting translation for 市廳
# Translation is city hall
#
# Now getting translation for 郵遞
# Translation is mail delivery
#
# Now getting translation for 銜
# Translation is title
#
# Now getting translation for 鮮膾
# Translation is fresh meat
#
# Now getting translation for 女同
# Translation is a girl's
#
# Now getting translation for 書館
# Translation is a library
#
# Now getting translation for 寄
# Translation is send
#
# Now getting translation for 話番號
# Translation is the number of words
#
# Now getting translation for 師
# Translation is master
#
# Now getting translation for 市場
# Translation is market
#
# Now getting translation for 萬
# Translation is ten thousand
#
# Now getting translation for 案內
# Translation is the inside
#
# Now getting translation for 常
# Translation is all the time
#
# Now getting translation for 地下鐵驛
# Translation is subway station
#
# Now getting translation for 掃
# Translation is sweep
#
# Now getting translation for 內
# Translation is inside
#
# Now getting translation for 廳
# Translation is office
#
# Now getting translation for 泳
# Translation is swim
#
# Now getting translation for 生
# Translation is bear
#
# Now getting translation for 洲
# Translation is continental
#
# Now getting translation for 遞
# Translation is hand over
#
# Now getting translation for 家族
# Translation is family
#
# Now getting translation for 心
# Translation is heart
#
# Now getting translation for 仁川空
# Translation is Incheon Airport
#
# Now getting translation for 跆
# Translation is kick
#
# Now getting translation for 親舊
# Translation is close friendship with the old.
#
# Now getting translation for 質問
# Translation is question
#
# Now getting translation for 工
# Translation is engineer
#
# Now getting translation for 鐵驛
# Translation is a railroad station
#
# Now getting translation for 醫
# Translation is heal
#
# Now getting translation for 小包
# Translation is a small bag
#
# Now getting translation for 料理師
# Translation is cook
#
# Now getting translation for 十一
# Translation is eleven
#
# Now getting translation for 館
# Translation is gallery
#
# Now getting translation for 午前
# Translation is before noon
#
# Now getting translation for 感
# Translation is feel
#
# Now getting translation for 自
# Translation is self
#
# Now getting translation for 約束
# Translation is constrain
#
# Now getting translation for 漢拏
# Translation is Chinese yam
#
# Now getting translation for 港
# Translation is harbor
#
# Now getting translation for 夫
# Translation is husband
#
# Now getting translation for 每
# Translation is every time
#
# Now getting translation for 看護
# Translation is nurse
#
# Now getting translation for 鳴
# Translation is chime
#
# Now getting translation for 話
# Translation is a word
#
# Now getting translation for 濠
# Translation is a mountain
#
# Now getting translation for 下鐵
# Translation is cast iron
#
# Now getting translation for 汽
# Translation is steam
#
# Now getting translation for 音樂
# Translation is music
#
# Now getting translation for 康
# Translation is fit
#
# Now getting translation for 電話
# Translation is Phone number.
#
# Now getting translation for 初等學
# Translation is elementary school
#
# Now getting translation for 空港
# Translation is an air port
#
# Now getting translation for 車場
# Translation is a parking lot
#
# Now getting translation for 色
# Translation is colour
#
# Now getting translation for 線
# Translation is thread
#
# Now getting translation for 今
# Translation is this day
#
# Now getting translation for 放
# Translation is let slide
#
# Now getting translation for 族
# Translation is family
#
# Now getting translation for 語
# Translation is language
#
# Now getting translation for 逸
# Translation is loose
#
# Now getting translation for 韓國語
# Translation is Korea language
#
# Now getting translation for 週
# Translation is week
#
# Now getting translation for 案
# Translation is plan
#
# Now getting translation for 拳
# Translation is punch
#
# Now getting translation for 公
# Translation is public
#
# Now getting translation for 務室
# Translation is office
#
# Now getting translation for 大學生
# Translation is a college student
#
# Now getting translation for 三
# Translation is three
#
# Now getting translation for 曜日
# Translation is observation day
#
# Now getting translation for 蹴球
# Translation is kick a ball
#
# Now getting translation for 街
# Translation is street
#
# Now getting translation for 地
# Translation is earth
#
# Now getting translation for 川
# Translation is stream
#
# Now getting translation for 飮
# Translation is 飮
#
# Now getting translation for 川空港
# Translation is Sichuan Airport
#
# Now getting translation for 葉書
# Translation is leaf book
#
# Now getting translation for 金曜日
# Translation is a golden day
#
# Now getting translation for 綠茶
# Translation is green tea
#
# Now getting translation for 籍
# Translation is register
#
# Now getting translation for 號線
# Translation is line
#
# Now getting translation for 前
# Translation is background
#
# Now getting translation for 敎室
# Translation is classroom
#
# Now getting translation for 初等
# Translation is elementary school
#
# Now getting translation for 記
# Translation is record
#
# Now getting translation for 票
# Translation is ticket
#
# Now getting translation for 五月
# Translation is May.
#
# Now getting translation for 金曜
# Translation is gold observation
#
# Now getting translation for 街坊
# Translation is neighborhood
#
# Now getting translation for 十二
# Translation is twelve
#
# Now getting translation for 試
# Translation is experimentally
#
# Now getting translation for 空冊
# Translation is an empty book
#
# Now getting translation for 會
# Translation is Yes, sir.
#
# Now getting translation for 聞
# Translation is smell
#
# Now getting translation for 携帶
# Translation is carry
#
# Now getting translation for 午
# Translation is afternoon
#
# Now getting translation for 濟
# Translation is save
#
# Now getting translation for 號
# Translation is number
#
# Now getting translation for 利用
# Translation is make use
#
# Now getting translation for 野
# Translation is wild
#
# Now getting translation for 球
# Translation is ball
#
# Now getting translation for 飛行機
# Translation is a flying machine
#
# Now getting translation for 溫
# Translation is warm
#
# Now getting translation for 寫眞
# Translation is photograph
#
# Now getting translation for 行員
# Translation is clerk
#
# Now getting translation for 國籍
# Translation is nationality
#
# Now getting translation for 來日
# Translation is the next day
#
# Now getting translation for 校
# Translation is school
#
# Now getting translation for 月曜日
# Translation is obsidian day
#
# Now getting translation for 宿舍
# Translation is hostel
#
# Now getting translation for 韓國
# Translation is 韓國
#
# Now getting translation for 洗
# Translation is wash
#
# Now getting translation for 十二月
# Translation is December
#
# Now getting translation for 果
# Translation is fruit
#
# Now getting translation for 麵
# Translation is countenance
#
# Now getting translation for 高等
# Translation is advanced
#
# Now getting translation for 灰
# Translation is dust
#
# Now getting translation for 冷麵
# Translation is cold noodles
#
# Now getting translation for 運轉
# Translation is run
#
# Now getting translation for 典
# Translation is book
#
# Now getting translation for 口
# Translation is mouth
#
# Now getting translation for 木曜
# Translation is observation
#
# Now getting translation for 地下鐵
# Translation is subway
#
# Now getting translation for 雨傘
# Translation is umbrella
#
# Now getting translation for 圖書
# Translation is book
#
# Now getting translation for 土曜
# Translation is earth observation
#
# Now getting translation for 子
# Translation is son
#
# Now getting translation for 市內
# Translation is the inner city
#
# Now getting translation for 自主
# Translation is independence
#
# Now getting translation for 敎
# Translation is teach
#
# Now getting translation for 跆拳道
# Translation is kickboxing
#
# Now getting translation for 醫師
# Translation is Doctor.
#
# Now getting translation for 登山
# Translation is climb a mountain
#
# Now getting translation for 住所
# Translation is residence
#
# Now getting translation for 事
# Translation is event
#
# Now getting translation for 牛
# Translation is cattle
#
# Now getting translation for 末
# Translation is the last
#
# Now getting translation for 感氣
# Translation is be moved by
#
# Now getting translation for 究員
# Translation is researcher
#
# Now getting translation for 出
# Translation is come out
#
# Now getting translation for 旅行
# Translation is travel
#
# Now getting translation for 舊
# Translation is old days
#
# Now getting translation for 至難
# Translation is the greatest difficulty
#
# Now getting translation for 麥酒
# Translation is ale
#
# Now getting translation for 本
# Translation is book
#
# Now getting translation for 寢臺
# Translation is bedside
#
# Now getting translation for 園
# Translation is garden
#
# Now getting translation for 記者
# Translation is a journalist
#
# Now getting translation for 一
# Translation is one
#
# Now getting translation for 年
# Translation is year
#
# Now getting translation for 筆
# Translation is brush
#
# Now getting translation for 新聞
# Translation is news
#
# Now getting translation for 日記
# Translation is diary
#
# Now getting translation for 冷藏
# Translation is refrigeration
#
# Now getting translation for 氣分
# Translation is air
#
# Now getting translation for 分
# Translation is share
#
# Now getting translation for 每日
# Translation is every day
#
# Now getting translation for 道
# Translation is way
#
# Now getting translation for 濟州
# Translation is Jeju Island
#
# Now getting translation for 日本語
# Translation is Japanese language
#
# Now getting translation for 投
# Translation is cast
#
# Now getting translation for 酒
# Translation is wine
#
# Now getting translation for 頭
# Translation is head
#
# Now getting translation for 自轉車
# Translation is a revolving car
#
# Now getting translation for 藏庫
# Translation is a repository
#
# Now getting translation for 拏
# Translation is 拏
#
# Now getting translation for 仁
# Translation is benevolence
#
# Now getting translation for 硏
# Translation is study
#
# Now getting translation for 庫
# Translation is bank
#
# Now getting translation for 火曜
# Translation is fire observation
#
# Now getting translation for 州島
# Translation is a state island
#
# Now getting translation for 昨年
# Translation is last year
#
# Now getting translation for 十萬
# Translation is one hundred thousand
#
# Now getting translation for 月
# Translation is month
#
# Now getting translation for 鉛筆
# Translation is pencil
#
# Now getting translation for 事務
# Translation is business
#
# Now getting translation for 漢
# Translation is Chinese
#
# Now getting translation for 問
# Translation is ask
#
# Now getting translation for 葡
# Translation is Portuguese
#
# Now getting translation for 來
# Translation is Come on.
#
# Now getting translation for 利
# Translation is benefit
#
# Now getting translation for 綠
# Translation is green
#
# Now getting translation for 牛乳
# Translation is milk
#
# Now getting translation for 土曜日
# Translation is obsidian day
#
# Now getting translation for 洗濯
# Translation is wash
#
# Now getting translation for 至
# Translation is come to
#
# Now getting translation for 洗濯所
# Translation is a washing house
#
# Now getting translation for 帶
# Translation is carry
#
# Now getting translation for 飮食
# Translation is 食eat
#
# Now getting translation for 電
# Translation is electricity
#
# Now getting translation for 女子
# Translation is a woman
#
# Now getting translation for 薔薇
# Translation is rose
#
# Now getting translation for 辭典
# Translation is dictionary
#
# Now getting translation for 濯所
# Translation is a washroom
#
# Now getting translation for 菜
# Translation is dish
#
# Now getting translation for 料
# Translation is material
#
# Now getting translation for 驗
# Translation is check
#
# Now getting translation for 食
# Translation is eat
#
# Now getting translation for 難
# Translation is difficult
#
# Now getting translation for 椅
# Translation is chair
#
# Now getting translation for 劇
# Translation is dramatic
#
# Now getting translation for 郵遞局
# Translation is post office
#
# Now getting translation for 點
# Translation is point
#
# Now getting translation for 日曜日
# Translation is obsidian day
#
# Now getting translation for 下鐵驛
# Translation is get off at a railroad station
#
# Now getting translation for 番
# Translation is several times
#
# Now getting translation for 料金
# Translation is material gold
#
# Now getting translation for 葡萄
# Translation is grape
#
# Now getting translation for 會社
# Translation is association
#
# Now getting translation for 雨
# Translation is rain
#
# Now getting translation for 車
# Translation is car
#
# Now getting translation for 釜
# Translation is kettle
#
# Now getting translation for 學生
# Translation is student
#
# Now getting translation for 高
# Translation is be high
#
# Now getting translation for 結婚
# Translation is get married
#
# Now getting translation for 旅
# Translation is brigades
#
# Now getting translation for 英語
# Translation is English
#
# Now getting translation for 病
# Translation is illness
#
# Now getting translation for 健
# Translation is strong
#
# Now getting translation for 畵
# Translation is paint
#
# Now getting translation for 突
# Translation is out of heart
#
# Now getting translation for 時間表
# Translation is timetable
#
# Now getting translation for 公園
# Translation is park
#
# Now getting translation for 行社
# Translation is a local government
#
# Now getting translation for 職
# Translation is duty
#
# Now getting translation for 月曜
# Translation is observation
#
# Now getting translation for 貨
# Translation is article
#
# Now getting translation for 看護師
# Translation is nurse
#
# Now getting translation for 業
# Translation is industry
#
# Now getting translation for 男便
# Translation is a man's stool
#
# Now getting translation for 溫突房
# Translation is thermal shock chamber
#
# Now getting translation for 空
# Translation is empty
#
# Now getting translation for 苦
# Translation is bitter
#
# Now getting translation for 二月
# Translation is February
#
# Now getting translation for 理師
# Translation is a management officer
#
# Now getting translation for 褐色
# Translation is brownish
#
# Now getting translation for 話番
# Translation is the last word
#
# Now getting translation for 苦悶
# Translation is anguish
#
# Now getting translation for 淸掃
# Translation is clean up
#
# Now getting translation for 氣
# Translation is air
#
# Now getting translation for 題
# Translation is title
#
# Now getting translation for 小
# Translation is small
#
# Now getting translation for 化
# Translation is change
#
# Now getting translation for 音
# Translation is sound
#
# Now getting translation for 帽
# Translation is hat
#
# Now getting translation for 只
# Translation is only
#
# Now getting translation for 學
# Translation is learn
#
# Now getting translation for 女
# Translation is woman
#
# Now getting translation for 百貨店
# Translation is department store
#
# Now getting translation for 釜山
# Translation is Busan, Republic of
#
# Now getting translation for 夕
# Translation is evening
#
# Now getting translation for 窓門
# Translation is 门door
#
# Now getting translation for 中學生
# Translation is a middle school student
#
# Now getting translation for 跆拳
# Translation is kickboxing
#
# Now getting translation for 店
# Translation is shop
#
# Now getting translation for 同生
# Translation is be of the same birth
#
# Now getting translation for 茶
# Translation is tea
#
# Now getting translation for 局
# Translation is department
#
# Now getting translation for 獨逸
# Translation is be alone
#
# Now getting translation for 究
# Translation is investigate
#
# Now getting translation for 水泳
# Translation is swim in the water
#
# Now getting translation for 二
# Translation is two
#
# Now getting translation for 他
# Translation is him
#
# Now getting translation for 拏山
# Translation is a mountain
#
# Now getting translation for 泳場
# Translation is swimming pool
#
# Now getting translation for 郵
# Translation is mail
#
# Now getting translation for 映
# Translation is reflect
#
# Now getting translation for 行
# Translation is Yes, sir.
#
# Now getting translation for 食堂
# Translation is dining room
#
# Now getting translation for 料理
# Translation is cook
#
# Now getting translation for 時
# Translation is time
#
# Now getting translation for 九
# Translation is nine
#
# Now getting translation for 束
# Translation is bundle
#
# Now getting translation for 映畵
# Translation is picture
#
# Now getting translation for 中學
# Translation is secondary school
#
# Now getting translation for 紙
# Translation is paper
#
# Now getting translation for 中國語
# Translation is Chinese language
#
# Now getting translation for 房
# Translation is house
#
# Now getting translation for 出發
# Translation is Let's go.
#
# Now getting translation for 美國
# Translation is the United States
#
# Now getting translation for 冷藏庫
# Translation is cold storage
#
# Now getting translation for 仁川空港
# Translation is Incheon Airport
#
# Now getting translation for 同
# Translation is agree
#
# Now getting translation for 濠洲
# Translation is Hao Chau, New Territories
#
# Now getting translation for 汽車
# Translation is an automobile
#
# Now getting translation for 休暇
# Translation is break
#
# Now getting translation for 國
# Translation is country
#
# Now getting translation for 化粧室
# Translation is make-up
#
# Now getting translation for 初等學生
# Translation is elementary school student
#
# Now getting translation for 硏究員
# Translation is researcher
#
# Now getting translation for 十
# Translation is ten
#
# Now getting translation for 下
# Translation is drop
#
# Now getting translation for 宿
# Translation is bed
#
# Now getting translation for 野球
# Translation is a wild ball
#
# Now getting translation for 親
# Translation is close
#
# Now getting translation for 銀行
# Translation is bank
#
# Now getting translation for 驛
# Translation is post
#
# Now getting translation for 恒
# Translation is constant
#
# Now getting translation for 質
# Translation is quality
#
# Now getting translation for 圖書館
# Translation is library
#
# Now getting translation for 駐
# Translation is stop
#
# Now getting translation for 帽子
# Translation is hat
#
# Now getting translation for 島
# Translation is island
#
# Now getting translation for 便紙
# Translation is paper
#
# Now getting translation for 電話番
# Translation is a telephone operator
#
# Now getting translation for 午後
# Translation is afternoon
#
# Now getting translation for 高等學生
# Translation is a college student
#
# Now getting translation for 坊
# Translation is circle
#
# Now getting translation for 五
# Translation is fives
#
# Now getting translation for 健康
# Translation is health
#
# Now getting translation for 水泳場
# Translation is a swimming pool
#
# Now getting translation for 約
# Translation is agree
#
# Now getting translation for 會社員
# Translation is a member of a society
#
# Now getting translation for 川空
# Translation is the sky of the river
#
# Now getting translation for 週日
# Translation is Sunday
#
# Now getting translation for 後
# Translation is afterwards
#
# Now getting translation for 寢
# Translation is bed
#
# Now getting translation for 日
# Translation is day
#
# Now getting translation for 舍
# Translation is abode
#
# Now getting translation for 濯
# Translation is wash
#
# Now getting translation for 護師
# Translation is nurse

# %%
len(translation_for_subseq)
# Out:
# 502

# %%
df_of_seq_translation = pd.DataFrame(translation_for_subseq.items()).rename(columns={
    0: 'hanja_subsequence',
    1: 'english_translation'
})

# %%
df_of_seq_translation.to_csv('../metadata/hanja_subsequence_translation.csv')
